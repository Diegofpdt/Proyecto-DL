# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast, Seq2SeqTrainingArguments, Seq2SeqTrainer, DataCollatorForSeq2Seq
from datasets import load_dataset, Dataset
from peft import get_peft_model, LoraConfig, TaskType, PeftModel
import torch

# %%
# !unzip mbart_lora_es_pt.zip -d mbart_lora_es_pt

# %%
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM,
)

# %%
model_name = "facebook/mbart-large-50-many-to-many-mmt"
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)
model = MBartForConditionalGeneration.from_pretrained(model_name)
model = get_peft_model(model, peft_config)

# %%
# !pip install -U datasets
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.33.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)

# %%
import huggingface_hub
huggingface_hub.login() # now you will be prompted to enter your token; enter it.
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
ds_es = load_dataset("openlanguagedata/flores_plus", "spa_Latn", split="dev")
ds_pt = load_dataset("openlanguagedata/flores_plus", "por_Latn", split="dev")
parallel_pt = [{"translation": {"es": e["text"], "pt": p["text"]}} for e, p in zip(ds_es, ds_pt)]
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Resolving data files:   0%|          | 0/219 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/213 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/219 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/213 [00:00<?, ?it/s]

# %%
dataset_pt = Dataset.from_list(parallel_pt).train_test_split(test_size=0.1, seed=42)
train_pt = dataset_pt["train"]
eval_pt = dataset_pt["test"]

# %%
tokenizer.src_lang = "es_XX"
tokenizer.tgt_lang = "pt_XX"

def tokenize_pt(batch):
    src = [x["es"] for x in batch["translation"]]
    tgt = [x["pt"] for x in batch["translation"]]
    inputs = tokenizer(src, truncation=True, padding="max_length", max_length=128)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(tgt, truncation=True, padding="max_length", max_length=128)
    inputs["labels"] = labels["input_ids"]
    return inputs

train_tokenized_pt = train_pt.map(tokenize_pt, batched=True)
eval_tokenized_pt = eval_pt.map(tokenize_pt, batched=True)
# Out:
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3959: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
training_args_pt = Seq2SeqTrainingArguments(
    output_dir="./mbart_lora_es_pt",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    learning_rate=5e-4,
    num_train_epochs=15,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs_pt",
    predict_with_generate=True,  # Importante para traducción
    fp16=torch.cuda.is_available(),  # Entrenamiento más rápido si tienes GPU
    save_total_limit=1,
    report_to="none",
    label_names=["labels"]
)

trainer_pt = Seq2SeqTrainer(
    model=model,
    args=training_args_pt,
    train_dataset=train_tokenized_pt,
    eval_dataset=eval_tokenized_pt,
    processing_class=tokenizer,
    data_collator=DataCollatorForSeq2Seq(tokenizer, model=model),
)

# %%
trainer_pt.train()
# Out:
#     <div>
#
#       <progress value='3375' max='3375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3375/3375 11:06, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>8.235757</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>8.224859</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.276700</td>
#       <td>8.226983</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.276700</td>
#       <td>8.234759</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8.091900</td>
#       <td>8.241047</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8.091900</td>
#       <td>8.258754</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>8.028200</td>
#       <td>8.266699</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>8.028200</td>
#       <td>8.279073</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>7.962200</td>
#       <td>8.283938</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>7.962200</td>
#       <td>8.295945</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>7.962200</td>
#       <td>8.305451</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7.930400</td>
#       <td>8.311280</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>7.930400</td>
#       <td>8.317265</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>7.902200</td>
#       <td>8.323857</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>7.902200</td>
#       <td>8.325553</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=3375, training_loss=8.013915364583333, metrics={'train_runtime': 667.1738, 'train_samples_per_second': 20.167, 'train_steps_per_second': 5.059, 'total_flos': 3657031200276480.0, 'train_loss': 8.013915364583333, 'epoch': 15.0})

# %%
model.save_pretrained("./mbart_lora_es_pt")
tokenizer.save_pretrained("./mbart_lora_es_pt")
print("✅ Adaptadores LoRA para Español → Portugués guardados.")
# Out:
# ✅ Adaptadores LoRA para Español → Portugués guardados.

# %%
model_name = "facebook/mbart-large-50-many-to-many-mmt"
tokenizer = MBart50TokenizerFast.from_pretrained(model_name)
base_model = MBartForConditionalGeneration.from_pretrained(model_name)
model = PeftModel.from_pretrained(base_model, "./mbart_lora_es_pt/mbart_lora_es_pt")

# %%
model.train()
for name, param in model.named_parameters():
    if "lora" in name:
        param.requires_grad = True

model.print_trainable_parameters()
# Out:
# trainable params: 1,179,648 || all params: 612,059,136 || trainable%: 0.1927

# %%
src_lang = "es_XX"
tgt_lang = "pt_XX"
tokenizer.src_lang = src_lang

# Función de traducción
def traducir(texto):
    inputs = tokenizer(texto, return_tensors="pt")
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    # Indicamos que la secuencia de salida debe comenzar en portugués
    generated_tokens = model.generate(
        **inputs,
        forced_bos_token_id=tokenizer.lang_code_to_id[tgt_lang],
        max_length=128
    )

    traduccion = tokenizer.decode(generated_tokens[0], skip_special_tokens=True)
    return traduccion

# %%
frases = [
    "Hola mundo",
    "¿Cómo estás?",
    "Me gusta aprender cosas nuevas.",
    "Estoy entrenando un modelo de traducción.",
    "La inteligencia artificial es fascinante."
]

for f in frases:
    print(f"ES: {f}")
    print(f"PT: {traducir(f)}\n")
# Out:
# ES: Hola mundo
# PT: Olá ao mundo!
#
# ES: ¿Cómo estás?
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-65-748322623.py in <cell line: 0>()
#       9 for f in frases:
#      10     print(f"ES: {f}")
# ---> 11     print(f"PT: {traducir(f)}\n")
#
# /tmp/ipython-input-64-2045760091.py in traducir(texto)
#       9
#      10     # Indicamos que la secuencia de salida debe comenzar en portugués
# ---> 11     generated_tokens = model.generate(
#      12         **inputs,
#      13         forced_bos_token_id=tokenizer.lang_code_to_id[tgt_lang],
#
# /usr/local/lib/python3.11/dist-packages/peft/peft_model.py in generate(self, **kwargs)
#    2144                 with self._enable_peft_forward_hooks(**kwargs):
#    2145                     kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 2146                     outputs = self.base_model.generate(**kwargs)
#    2147             else:
#    2148                 if "input_ids" not in kwargs:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, custom_generate, **kwargs)
#    2410         if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    2411             # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 2412             model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    2413                 inputs_tensor, model_kwargs, model_input_name, generation_config
#    2414             )
#
# /usr/local/lib/python3.11/dist-packages/transformers/generation/utils.py in _prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     852         encoder_kwargs["return_dict"] = True
#     853         encoder_kwargs[model_input_name] = inputs_tensor
# --> 854         model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)  # type: ignore
#     855
#     856         return model_kwargs
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mbart/modeling_mbart.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1053                     )
#    1054                 else:
# -> 1055                     layer_outputs = encoder_layer(
#    1056                         hidden_states,
#    1057                         attention_mask,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/mbart/modeling_mbart.py in forward(self, hidden_states, attention_mask, layer_head_mask, output_attentions)
#     566         residual = hidden_states
#     567         hidden_states = self.final_layer_norm(hidden_states)
# --> 568         hidden_states = self.activation_fn(self.fc1(hidden_states))
#     569         hidden_states = nn.functional.dropout(hidden_states, p=self.activation_dropout, training=self.training)
#     570         hidden_states = self.fc2(hidden_states)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
ds_gl = load_dataset("openlanguagedata/flores_plus", "glg_Latn", split="dev")
parallel_gl = [{"translation": {"es": e["text"], "gl": g["text"]}} for e, g in zip(ds_es, ds_gl)]

dataset_gl = Dataset.from_list(parallel_gl).train_test_split(test_size=0.1, seed=42)
train_gl = dataset_gl["train"]
eval_gl = dataset_gl["test"]
# Out:
# Resolving data files:   0%|          | 0/219 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/213 [00:00<?, ?it/s]
# glg_Latn.parquet:   0%|          | 0.00/123k [00:00<?, ?B/s]
# glg_Latn.parquet:   0%|          | 0.00/128k [00:00<?, ?B/s]
# Generating dev split:   0%|          | 0/997 [00:00<?, ? examples/s]
# Generating devtest split:   0%|          | 0/1012 [00:00<?, ? examples/s]

# %%
tokenizer.src_lang = "es_XX"
tokenizer.tgt_lang = "gl_ES"

def tokenize_gl(batch):
    src = [x["es"] for x in batch["translation"]]
    tgt = [x["gl"] for x in batch["translation"]]
    inputs = tokenizer(src, truncation=True, padding="max_length", max_length=128)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(tgt, truncation=True, padding="max_length", max_length=128)
    inputs["labels"] = labels["input_ids"]
    return inputs

train_tokenized_gl = train_gl.map(tokenize_gl, batched=True)
eval_tokenized_gl = eval_gl.map(tokenize_gl, batched=True)
# Out:
# Map:   0%|          | 0/897 [00:00<?, ? examples/s]
# /usr/local/lib/python3.11/dist-packages/transformers/tokenization_utils_base.py:3959: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   warnings.warn(
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]

# %%
training_args_gl = Seq2SeqTrainingArguments(
    output_dir="./mbart_lora_es_gl",
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    learning_rate=5e-4,
    num_train_epochs=15,
    eval_strategy="epoch",
    save_strategy="epoch",
    logging_dir="./logs_gl",
    predict_with_generate=True,
    fp16=torch.cuda.is_available(),
    save_total_limit=1,
    report_to="none",
    label_names=["labels"]
)

trainer_gl = Seq2SeqTrainer(
    model=model,
    args=training_args_gl,
    train_dataset=train_tokenized_gl,
    eval_dataset=eval_tokenized_gl,
    processing_class=tokenizer,
    data_collator=DataCollatorForSeq2Seq(tokenizer, model=model),
)

# %%
trainer_gl.train()
model.save_pretrained("./mbart_lora_es_gl")
tokenizer.save_pretrained("./mbart_lora_es_gl")
# Out:
#     <div>
#
#       <progress value='3375' max='3375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3375/3375 10:10, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>8.279472</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>8.275163</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>8.177100</td>
#       <td>8.288431</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>8.177100</td>
#       <td>8.293840</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>8.029600</td>
#       <td>8.303224</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>8.029600</td>
#       <td>8.321163</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>7.972700</td>
#       <td>8.342236</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>7.972700</td>
#       <td>8.353626</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>7.903800</td>
#       <td>8.365123</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>7.903800</td>
#       <td>8.373678</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>7.903800</td>
#       <td>8.381953</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>7.868700</td>
#       <td>8.385201</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>7.868700</td>
#       <td>8.392562</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>7.842300</td>
#       <td>8.395890</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>7.842300</td>
#       <td>8.397739</td>
#     </tr>
#   </tbody>
# </table><p>
# ('./mbart_lora_es_gl/tokenizer_config.json',
#  './mbart_lora_es_gl/special_tokens_map.json',
#  './mbart_lora_es_gl/sentencepiece.bpe.model',
#  './mbart_lora_es_gl/added_tokens.json',
#  './mbart_lora_es_gl/tokenizer.json')

# %%
pip install evaluate sacrebleu
# Out:
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.4)
# Collecting sacrebleu
#   Downloading sacrebleu-2.5.1-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.0.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.3.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.33.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (24.2)
# Collecting portalocker (from sacrebleu)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (2024.11.6)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (0.9.0)
# Collecting colorama (from sacrebleu)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from sacrebleu) (5.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (18.1.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.11.15)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.6.15)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Downloading sacrebleu-2.5.1-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.1/104.1 kB 6.2 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: portalocker, colorama, sacrebleu
# Successfully installed colorama-0.4.6 portalocker-3.2.0 sacrebleu-2.5.1

# %%
from evaluate import load

# %%
def test_translation_batch(sentences_es, references_gl, model_path="./mbart_lora_es_gl"):
    try:
        # Cargar modelo base + adaptadores LoRA
        base_model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
        model = PeftModel.from_pretrained(base_model, model_path)
        model.eval()
        device = "cuda" if torch.cuda.is_available() else "cpu"
        model.to(device)

        # Cargar tokenizer
        tokenizer = MBart50TokenizerFast.from_pretrained(model_path)
        inputs = tokenizer(sentences_es, return_tensors="pt", padding=True, truncation=True).to(device)

        # Generar traducciones
        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=128,
                num_beams=4,
                early_stopping=True,
                do_sample=False
            )

        translations = [tokenizer.decode(out, skip_special_tokens=True) for out in outputs]

        # Mostrar resultados
        for src, pred, ref in zip(sentences_es, translations, references_gl):
            print(f"EN: {src}")
            print(f"GL (pred): {pred}")
            print(f"GL (ref):  {ref}")
            print("-" * 60)

        # Calcular métricas BLEU y chrF en lote
        print("\n📊 Métricas globales:")
        bleu = load("bleu")
        chrf = load("chrf")

        bleu_score = bleu.compute(predictions=translations, references=[[r] for r in references_gl])
        chrf_score = chrf.compute(predictions=translations, references=references_gl)

        print(f"BLEU: {bleu_score['bleu']:.4f}")
        print(f"chrF: {chrf_score['score']:.2f}")

    except Exception as e:
        print(f"❌ Error en traducción: {e}")

# %%
ds_es = load_dataset("openlanguagedata/flores_plus", "spa_Latn", split="devtest[:50]")
ds_gl = load_dataset("openlanguagedata/flores_plus", "glg_Latn", split="devtest[:50]")

# Tomar una muestra de 50 ejemplos para visualización
sample_es = ds_es["text"][:50]
sample_gl = ds_gl["text"][:50]
# Out:
# Resolving data files:   0%|          | 0/219 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/213 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/219 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/213 [00:00<?, ?it/s]

# %%
test_translation_batch(sample_es, sample_gl)
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# EN: «Actualmente, tenemos ratones de cuatro meses de edad que antes solían ser diabéticos y que ya no lo son», agregó.
# GL (pred): «Agora temos ratos de catro meses de idade que antes sufrían diabetes e xa non o están», añadiu.
# GL (ref):  "Agora temos ratos de 4 meses que xa non son diabéticos, pero que no seu momento si que o foron", engadiu.
# ------------------------------------------------------------
# EN: La investigación todavía se ubica en su etapa inicial, conforme indicara el Dr. Ehud Ur, docente en la carrera de medicina de la Universidad de Dalhousie, en Halifax, Nueva Escocia, y director del departamento clínico y científico de la Asociación Canadiense de Diabetes.
# GL (pred): A investigación aínda está na súa etapa inicial, afirma o Dr. Ehud Ur, profesor de medicina de carrera na Universidade de Dalhousie en Halifax ( Nova Escocia) e director do departamento clínico e científico da Diabetes Association Canada.
# GL (ref):  O Dr. Ehud Ur, profesor de medicina na Universidade Dalhousie en Halifax (Nova Escocia) e presidente da división clínica e científica da Asociación canadense contra a diabetes advertiu de que a investigación aínda está nunha fase inicial.
# ------------------------------------------------------------
# EN: Al igual que otros especialistas, es escéptico acerca de si la diabetes tiene cura y remarca que estos descubrimientos no son relevantes para quienes que ya padecen de diabetes de tipo 1.
# GL (pred): Tal como outros científicos, tamén está esceptico sobre se o diabetes ten cura e observa que estas descobertas non son relevantes para os que xa teñan diabetes de tipo 1.
# GL (ref):  Do mesmo xeito que outros expertos, amósase escéptico de que a diabetes teña cura e apunta que estes achados non son relevantes para as persoas que xa teñen diabetes de tipo 1.
# ------------------------------------------------------------
# EN: El lunes, Sara Danius, secretaria permanente del Comité por el Nobel de Literatura de la Academia Sueca, declaró públicamente en un programa radiofónico de Sveriges, en Suecia, que, al no poder contactar directamente con Bob Dylan para comunicarle el premio en Literatura 2016, el comité había abandonado sus esfuerzos por comunicarse con él.
# GL (pred): O Secretario Permanente do Comité do Nobel de Literatura da Academia Sueca, Sara Danius, declarou publicamente nun spot radiofónico de Sveriges (Suecia) o luns que, de non poder contactar directamente a Bob Dylan para obter o premio de Literatura 2016 -, o Comité abandonou as súas esforzos por acadar con él.
# GL (ref):  O pasado luns, Sara Danius, a secretaria permanente do Comité do Nobel de Literatura da Academia Sueca, anunciou en público durante unha entrevista no programa de radio da cadea Sveriges Radio en Suecia que o comité, ao non lograr contactar directamente con Bob Dylan acerca do outorgamento do Premio Nobel de Literatura 2016, decidira abandonar os intentos de falar con el.
# ------------------------------------------------------------
# EN: Danius declaró: «Actualmente no estamos haciendo nada. Llamé y envié correos electrónicos a su asistente más cercano y recibí contestaciones muy cordiales. Por el momento, eso es sin dudas suficiente».
# GL (pred): Danius afirmou: «Agora non estamos facendo nada. Llamemos e enviou correos electrónicos ao seu axudante máis próximo e obtiven respostas moi cordiales. Por agora, iso é indudablemente suficiente».
# GL (ref):  Danius afirmou: «Agora mesmo non estamos a facer nada. Chamei e envieille correos electrónicos ao seu colaborador máis próximo e recibín respostas moi amables. De momento, con iso abonda».
# ------------------------------------------------------------
# EN: Con anterioridad, el director ejecutivo de Ring, Jamie Siminoff, mencionó que la compañía había iniciado a raíz de que el timbre de su entrada no podía oírse desde la tienda que tenía montada en su garaje.
# GL (pred): O director executivo de Ring, Jamie Siminoff, mencionou previamente que a empresa se iniciou a causa de que o timbre da entrada non puidese ser oído da tenda que montaba no seu garaxe.
# GL (ref):  Previamente, o director executivo de Ring, Jamie Siminoff, destacou que a empresa naceu cando non puido oír o timbre da porta desde o seu taller no garaxe.
# ------------------------------------------------------------
# EN: Él dijo que construyó un timbre wifi.
# GL (pred): Dixo que fixo unha conexión inalámbrica.
# GL (ref):  Afirmou que construíu un timbre wifi.
# ------------------------------------------------------------
# EN: Siminoff declaró que las ventas se dispararon luego de su aparición en un episodio de Shark Tank en el año 2013, en el que el panel del programa televisivo se negó a financiar la puesta en marcha de la compañía.
# GL (pred): Siminoff afirmou que os pedidos explotaron despois de que aparecese no episodio de Shark Tank no 2013, no que o grupo do programa de televisión refusou financiar a puesta en marcha da compañía.
# GL (ref):  Siminoff afirmou que as vendas se incrementaron despois da súa aparición en 2013 no episodio Shark Tank, no que o panel do programa rexeitou financiar a empresa emerxente.
# ------------------------------------------------------------
# EN: Hacia fines del año 2017, Siminoff hizo una aparición en el canal de compras televisadas QVC.
# GL (pred): Ao final do 2017, Siminoff apareceu no canal de compras de televisión QVC.
# GL (ref):  Foi a finais de 2017 cando Siminoff apareceu na canle de compras por televisión QVC.
# ------------------------------------------------------------
# EN: Ring también llegó a un acuerdo en el litigio con la compañía de seguridad de la competencia, ADT Corporation.
# GL (pred): Ring tamén fixo acordo na disputa coa compañía de seguridade de competición ADT Corporation.
# GL (ref):  Ring tamén chegou a un acordo extraxudicial cunha empresa de seguridade competidora, a ADT Corporation.
# ------------------------------------------------------------
# EN: Al día de hoy no se ha demostrado a ciencia cierta que algún fármaco sea adecuado para tratar la infección existente causada por ébola, aun cuando existe una vacuna experimental que pareciera ser capaz de disminuir la mortalidad causada por esa enfermedad.
# GL (pred): O fármaco existente para a infección por ébola non ten sido probado con certeza ata o presente, aínda que existen unha vacina experimental que parece ser capaz de reducir a mortalidade por esa enfermidade.
# GL (ref):  Aínda que os indicios apuntan a que unha vacina experimental é capaz de reducir a mortalidade causada polo ébola, ata o momento, ningún medicamento demostrou de xeito evidente a súa capacidade para tratar esa infección.
# ------------------------------------------------------------
# EN: Zmapp, un combinado de anticuerpos, tuvo un prometedor resultado de campo al principio, pero estudios los formales demostraron que era menos beneficioso de lo que se esperaba para prevenir la muerte.
# GL (pred): Unha combinación de anticorpos compró un resultado prometedor en campo ao principio, pero as análises oficiales demostraron que resultou menos do que se esperaba para previr a morte.
# GL (ref):  Un cóctel de anticorpos, o ZMapp, presentou nun principio resultados prometedores nese campo, pero outros estudos formais apuntaron a que presentaba menos beneficios dos esperados na prevención da mortalidade.
# ------------------------------------------------------------
# EN: En el ensayo PALM, la función de Zmapp fue de control, es decir, que los científicos lo utilizaron como base y compararon con él los otros tres tratamientos.
# GL (pred): Na proba PALM, a función de Zmapp foi controlar, pois os científicos a empregaron como base para comparar os outros tres tratamentos.
# GL (ref):  No xuízo contra PALM, ZMapp actuou como control, é dicir, os científicos empregárono como liña base e compararon tres outros medicamentos con el.
# ------------------------------------------------------------
# EN: USA Gymnastics respalda la nota del Comité Olímpico de los Estados Unidos y reconoce que resulta imperioso que la familia olímpica fomente un entorno seguro para todos nuestros deportistas.
# GL (pred): USA Gymnastics apoia a petición do Comité Olímpico dos EE. UU. e afirma que é imperioso que a familia olímpica cree un entorno seguro para todos os nosos atletas.
# GL (ref):  USA Gymnastics apoia a carta do Comité Olímpico dos EE. UU. e acepta a imperiosa necesidade de que a familia olímpica fomente unha contorna segura para todas as atletas.
# ------------------------------------------------------------
# EN: Coincidimos con la declaración de la USOC de que los intereses de los atletas, los clubes y sus deportes, pueden ser atendidos más apropiadamente si se avanza con cambios significativos dentro de nuestra organización, en lugar del retiro de las certificaciones.
# GL (pred): Coincidimos coa declaración da USOC de que os intereses dos atletas, os clubes e os seus deportes poden ser máis axeitados se avanzan con cambios significativos na nosa organización máis ca o retiro dos certificados.
# GL (ref):  Concordamos coa declaración do USOC que afirma que os intereses dos nosos atletas e clubs, e do seu deporte, poderían estar mellor atendidos pensando no futuro cun cambio significativo dentro na nosa organización, en lugar da retirada da certificación.
# ------------------------------------------------------------
# EN: USA Gymnastics respalda a una investigación independiente que puede esclarecer de qué modo el abuso de la proporción que los sobrevivientes de Larry Nassa describieron con tanto coraje pudo haber pasado sin ser visto por tanto tiempo y acepta cualquier cambio necesario y adecuado.
# GL (pred): USA Gymnastics apoia unha investigación independiente que poida explicar como é posible que o abuso da porción que os sobreviventes de Larry Nassa describían con tanto corazón pasara sen ser visto por tanto tempo e aceptase calquera cambio necesario e correcto.
# GL (ref):  USA Gymnastics apoia unha investigación independente que podería aclarar como uns abusos das dimensións descritas con tanta coraxe polas superviventes de Larry Nassar puideron pasar desapercibidas durante tanto tempo e acolle todos os cambios necesarios e apropiados.
# ------------------------------------------------------------
# EN: La meta de USA Gymnastics y USOC es la misma: lograr que la gimnasia y otros deportes sean lo más seguro posible para que los atletas persigan sus sueños en un entorno protegido, positivo y potenciado.
# GL (pred): A meta de USA Gymnastics e USOC é a mesma: conseguir que a Gimnasia e outros deportes sexan o máis seguros posible para que os atletas fagan os seus soños nun entorno seguro, positivo e forte.
# GL (ref):  O USA Gymnastics e o USOC teñen o mesmo obxectivo: facer que a ximnasia como deporte, así como outros máis, sexan o máis seguros posible para que as atletas poidan seguir os seus soños nunha contorna segura, positiva e empoderada.
# ------------------------------------------------------------
# EN: Durante los años 60, Brzezinski trabajó para John F. Kennedy en el puesto de asesor y, posteriormente, para el gobierno de Lyndon B. Johnson.
# GL (pred): Nos anos 60, Brzezinski trabaou para John F. Kennedy como axeitor e, posteriormente, para o goberno de Lyndon B. Johnson.
# GL (ref):  Foi ao longo da década dos 60 cando Brzezinski traballou para John F. Kennedy en calidade de asesor e, deseguido, para a administración de Lyndon B. Johnson.
# ------------------------------------------------------------
# EN: Asesoró a Carter en materia de política exterior en las elecciones de 1976. Posteriormente, trabajó como asesor de seguridad nacional (ASN) entre 1977 y 1981, luego de Henry Kissinger.
# GL (pred): Axudau a Carter en política exterior nas eleccións de 1976. Posteriormente, entre 1977 e 1981, e despois de Henry Kissinger, actuou como axudante para a seguridade nacional (dessaudade nacional) (dessaudade nacional).
# GL (ref):  Durante as eleccións de 1976, asesorou a Carter sobre política exterior e, posteriormente, traballou como Asesor de Seguridade Nacional (NSA) entre 1977 e 1981, como sucesor de Henry Kissinger.
# ------------------------------------------------------------
# EN: Como consejero de seguridad nacional, asistió a Carter en el manejo diplomático de asuntos internacionales, como los Acuerdos de Camp David de 1978, la normalización de las relaciones entre Estados Unidos y China a fines de la década de 1970, la Revolución iraní de 1979, la que llevó a una crisis de rehenes en Irán, y la invasión soviética en Afganistán, en 1979.
# GL (pred): Como consule de seguridade nacional, assistiu a Carter na dirección diplomática de asuntos internacionais, como os Acuerdos de Camp David de 1978, a normalización das relacións entre os EE. UU. e China baixo a década dos 70, a Revolución iraniana de 1979 que causou unha crise de rehenes en Irán e a invasión soviética en Afganistán en 1979.
# GL (ref):  Na Axencia Nacional de Seguridade, asistiu a Carter na xestión diplomática de temas internacionais, como os Acordos de Camp David, en 1978; a normalización das relacións entre EE. UU. e China ata finais dos anos 70; a revolución iraniana, que desencadeou a crise dos reféns iranianos, en 1979; e a invasión soviética de Afganistán, en 1979.
# ------------------------------------------------------------
# EN: El filme, protagonizado por Tyan Gosling y Emma Stone, fue nominado en todas las categorías más importantes.
# GL (pred): O filme, co protagonistas Tyan Gosling e Emma Stone, foi nominado en todas as categorías máis importantes.
# GL (ref):  A película, cos actores Ryan Gosling e Emma Stone, foi nominada en todas as principais categorías.
# ------------------------------------------------------------
# EN: Gosling y Stone fueron nominados como Mejor Actor y Mejor Actriz, respectivamente.
# GL (pred): Gosling e Stone foron nominados como mellores actores e mellor actriz, respectivamente.
# GL (ref):  Gosling e Stone recibiron nominacións a Mellor Actor e Actriz, respectivamente.
# ------------------------------------------------------------
# EN: Entre las demás nominaciones se encuentran Mejor película, Mejor director, Mejor cinematografía, Mejor diseño de vestuario, Mejor edición de películas, Mejor partitura original, Mejor diseño de producción, Mejor edición de sonido, Mejor mezcla de sonido y Mejor guion original.
# GL (pred): As outras premios incluían mellor película, mellor director, mellor cineasta, mellor deseño de vestuario, mellor edición de películas, mellor versión orixinal de música, mellor deseño de produción, mellor edición de son, mellor combinación de son e mellor guión orixinal.
# GL (ref):  Outras nominacións tamén incluíron Mellor película, Mellor director, Mellor cinematografía, Mellor deseño de vestiario, Mellor edición, Mellor banda sonora orixinal, Mellor deseño de produción, Mellor edición de son, Mellor mestura de son e Mellor guión orixinal.
# ------------------------------------------------------------
# EN: Fueron dos las nominadas a mejor canción original: Audición (Los tontos que sueñan) y Ciudad de estrellas. El estudio Lionsgate fue nominado 26 veces, superando a cualquier otro estudio.
# GL (pred): Dous cancións foron nominadas para a mellor canción original: Audición (Los tontos que soñan) e Ciudad de estrelas. O estudio Lionsgate foi nominado 26 veces, superando calquera outro estudio.
# GL (ref):  Dúas cancións da película, Audition (The Fools Who Dream) e City of Stars, foron nominadas a mellor canción orixinal. O estudio Lionsgate recibiu 26 nominacións: máis ca ningún outro estudio.
# ------------------------------------------------------------
# EN: El domingo por la noche, en un anuncio realizado mediante el secretario de prensa, el presidente de los Estados Unidos de América, Donald Trump, comunicó que las tropas estadounidenses se retirarían de Siria.
# GL (pred): O domingo por noite, o presidente dos EE. UU., Donald Trump, comunicou mediante un comunicado do secretario de prensa que as tropas dos EE. UU. se retirarían da Siria.
# GL (ref):  A última hora do domingo, o presidente dos EE. UU., Donald Trump, anunciou a través dunha declaración emitida polo secretario de prensa que as tropas estadounidenses ían abandonar Siria.
# ------------------------------------------------------------
# EN: El anuncio se hizo tras la conversación telefónica que Trump mantuvo con con el presidente de Turquía, Recep Tayyip Erdoğan.
# GL (pred): O anuncio fíxose tras a conversa telefónica que Trump fixo co presidente de Turquía Recep Tayyip Erdoğan.
# GL (ref):  Este anuncio realizouse despois de que Trump falase por teléfono co presidente turco Recep Tayyip Erdoğan.
# ------------------------------------------------------------
# EN: Turquía asumiría, además, la vigilancia de los militantes del ISIS que fueron capturados, a quienes las naciones europeas, conforme indica el comunicado, les denegó su repatriación.
# GL (pred): Turquía tamén asumiría a vigilancia dos militantes do ISIS capturados, aos que as nacións europeas han denegado o seu repatrio, según o comunicado.
# GL (ref):  Turquía tamén se encargaría da custodia dos soldados do EIIL que, segundo a declaración, os países europeos rexeitaron repatriar.
# ------------------------------------------------------------
# EN: Además de confirmar que al menos algunos dinosaurios eran plumíferos, una teoría ya generalizada, también ofrece datos específicos que los fósiles por lo general no ofrecen, como su color y su estructura tridimensional.
# GL (pred): Ademais de confirmar que polo menos algúns dos dinosauros eran plumiferos, unha teoría aínda generalizada ofrece datos específicos que os restos xeralmente non ofrecen, como o seu cor e a súa estrutura tridimensional.
# GL (ref):  Isto confirma que como mínimo algúns dinosauros tiñan plumas (unha teoría xa estendida) e ademais proporciona outros datos que, polo xeral, os fósiles non nos ofrecen, como poden ser a cor e a disposición tridimensional.
# ------------------------------------------------------------
# EN: Según los especialistas, este animal tiene un plumaje de color castaño en la zona superior y una tonalidad pálida o carotenoide en la parte de abajo.
# GL (pred): Os científicos cren que o animal ten unha capa de carón en cima e unha tonalidade pálida ou carotenoide en baixo.
# GL (ref):  . Os científicos afirman que as plumas do animal eran de cor castaña na parte superior e na parte inferior pálidas ou de cor carotenoide.
# ------------------------------------------------------------
# EN: Asimismo, el hallazgo permite comprender mejor la evolución de las plumas de las aves.
# GL (pred): Os achados tamén permiten comprender mellor a evolución das plumas das aves.
# GL (ref):  O achado tamén ofrece unha perspectiva sobre como evolucionaron as plumas nos paxaros.
# ------------------------------------------------------------
# EN: Dado que el plumaje de los dinosaurios no tiene un eje bien desarrollado, denominado raquis, pero sí presenta otros rasgos de las plumas (cerdas y bárbulas), los investigadores llegaron a la conclusión de que es probable que el raquis sea el resultado de un desarrollo evolutivo posterior de estas otras características.
# GL (pred): O plumax dos dinosauros non ten un eixo moi desenvolvido, chamado raquis, aínda que presenta outros rasgos do plumax (cerdas e barbarbulas), así que os investigadores concluíron que era probable que o raquis fose o resultado dun posterior desenvolvemento evolutivo destes outros trazos.
# GL (ref):  Como as plumas dos dinosauros non teñen un canón ben desenvolvido, chamado raquis, pero si outras características propias das plumas (barbas e bárbulas), os investigadores deduciron que o raquis probablemente represente unha evolución posterior a esas outras características.
# ------------------------------------------------------------
# EN: La estructura que presenta el plumaje sugiere que su función no estaba relacionada con el vuelo, sino que las usaban para regular la temperatura o como indicador de la misma. Los investigadores sostienen que, aunque se trata de la cola de un dinosaurio joven, la muestra analizada presenta rasgos del plumaje de un adulto y no de un polluelo.
# GL (pred): A estrutura que presenta o plumaxe suxire que tiñan función non relacionada co voo, senón para regular a temperatura ou o seu indicador. Aínda que se trata da cola dun dinosauro jovem, os investigadores afirman que a tela analizada presenta trazos do plumaxe dun adulto e non dun polluello.
# GL (ref):  A estrutura das plumas suxire que non se usaban para voar, senón para regular a temperatura ou como enfeite. Os investigadores suxeriron que, aínda que se trata da cola dun dinosauro novo, a mostra presenta plumaxe adulta e non se trata de penuxe dunha cría nova.
# ------------------------------------------------------------
# EN: Las apreciaciones de los expertos fueron que, aun cuando se trata de la cola de un dinosaurio de corta edad, la muestra ilustra más el plumaje de un adulto que el de un polluelo.
# GL (pred): Os expertos consideraron que aínda que se trata da cola dun dinosauro pequeno, a mostra resulta máis clara sobre o plumaje dun adulto que dun coiro.
# GL (ref):  Os investigadores suxeriron que, aínda que se trata da cola dun dinosauro novo, a mostra presenta plumaxe adulta e non se trata de penuxe dunha cría nova.
# ------------------------------------------------------------
# EN: En la mañana de ayer, en Gaziantep, Turquía, un coche bomba mató a dos oficiales de policía e hirió a más de otras veinte personas.
# GL (pred): A mañá, na mañá, en Gaziantep (Turquía), un coche bomba asasinou a dous oficiales da policía e fixo da vida a máis de vinte persoas.
# GL (ref):  Un coche bomba detonado onte pola mañá nunha comisaría de policía en Gaziantep (Turquía) saldouse con dous axentes mortos e máis de vinte persoas feridas.
# ------------------------------------------------------------
# EN: Desde el gobierno informaron que diecinueve de las personas heridas eran policías.
# GL (pred): Os informes do goberno afirman que nove das doentes foron policías.
# GL (ref):  Desde a oficina do gobernador afirmouse que dezanove feridos foron axentes da policía.
# ------------------------------------------------------------
# EN: La policía informó que el sospechoso por el ataque es un supuesto militante de Daish (ELIL).
# GL (pred): A policía declarou que o sospechoso do ataque era un suposto militante de Daish (ELIL).
# GL (ref):  A policía confirmou a sospeita de que un presunto militante do Dáesh (EIIL) foi o responsable do ataque.
# ------------------------------------------------------------
# EN: Se descubrió que el sol se regía por los mismos principios básicos que otras estrellas: los únicos factores que impulsaban su actividad dentro del sistema eran su luminosidad y su rotación.
# GL (pred): O Sol descubriuse teniendo as mesmas ideas básicas que outras estrelas: os únicos factores que impulsaban a súa actividade no sistema eran a luminosidade e a rotación.
# GL (ref):  Descubriron que o Sol segue os mesmos principios básicos que o resto das estrelas: comprobouse que a actividade de todas as estrelas no sistema se rexe pola súa luminosidade, rotación e nada máis.
# ------------------------------------------------------------
# EN: La intensidad de la luz y la rotación se combinan para calcular el número de Rossby de una estrella, vinculado al flujo de plasma.
# GL (pred): A intensidade de luz e a rotación resultan combinadas para calcular o número de Rossby dunha estrela asociada ao fluxo de plasma.
# GL (ref):  A luminosidade e a rotación empréganse conxuntamente para determinar un número estelar Rossby, relacionado co fluxo de plasma.
# ------------------------------------------------------------
# EN: A menor número de Rossby, menor es la actividad de la estrella en relación con sus inversiones magnéticas.
# GL (pred): Ao facer máis de Rossby, a actividade da estrela co respecto aos investimentos magnéticos é menor.
# GL (ref):  Canto máis baixo sexa o número Rossby, menor actividade terá a estrela en relación ás inversións magnéticas.
# ------------------------------------------------------------
# EN: Iwasaki debió enfrentarse con numerosos problemas durante su viaje.
# GL (pred): Durante a viaxe, Iwasaki tivo moitos problemas.
# GL (ref):  Durante a súa viaxe, Iwasaki meteuse en problemas en numerosas ocasións.
# ------------------------------------------------------------
# EN: Lo asaltaron piratas, lo mordió un perro con rabia en el Tíbet, escapó del matrimonio en Nepal y lo detuvo la policía en India.
# GL (pred): Foi matado por piratas, en Tibet por un rapaz que padecíarabia, foi violado no Nepal durante a casada e arrestado pola policía en India.
# GL (ref):  Roubárono os piratas, un can rabioso atacouno no Tíbet, escapou dunha voda en Nepal e foi arrestado na India.
# ------------------------------------------------------------
# EN: El 802.11n estándar funciona tanto en frecuencias de 2.4Ghz como 5.0Ghz.
# GL (pred): O estándar 802.11n funciona tanto en freuncias de 2.4Ghz coma 5.0Ghz.
# GL (ref):  A norma 802.11n funciona tanto coas frecuencias de 2,4 GHz e 5,0 GHz.
# ------------------------------------------------------------
# EN: Esto hará posible su compatibilidad con versiones anteriores de 802.11a, 802.11b y 802.11g; ello en la medida en que la estación base tenga radios duales.
# GL (pred): Isto fará posible a compatibilidade con versións anteriores de 802.11a, 802.11b e 802.11g, xa que a estación de base ten radios duales.
# GL (ref):  Isto permitirá unha compatibilidade retroactiva con 802.11a, 802.11b e 802.11g, sempre que esa estación base teña radios duais.
# ------------------------------------------------------------
# EN: Las velocidades del estándar 802.11n son mucho más altas que las alcanzadas por los que lo precedieron, con un rendimiento teórico máximo de 600 Mbps.
# GL (pred): As velocidades do standard 802.11n son moito máis altas que as anteriores, con un rendemento teórico máximo de 600 Mbps.
# GL (ref):  As velocidades de 802,11n son considerablemente máis rápidas que as dos seus predecesores cunha produción teórica máxima de 600Mbit/s.
# ------------------------------------------------------------
# EN: Duvall, que está casado y tiene dos hijos adultos, no causó una buena impresión a Miller, que fue a quien le relató la historia.
# GL (pred): Duvall, que é casado e ten dous fillos adultos, fixo mala impresión no caso de Miller, ao que foi quen lle contou a historia.
# GL (ref):  Duvall, casado e con dous fillos adultos, non deixou unha boa impresión en Miller, con quen estaba relacionada a historia.
# ------------------------------------------------------------
# EN: Al pedirle un comentario, Miller dijo: «Mike habla mucho durante la audiencia… Estaba preparándome, así que en verdad no pude escuchar lo que decía».
# GL (pred): Miller, ao pedir comentarios: «Mike fala moito na audiencia... Estaba a prepararme para non poder escoitar o que lle dicía».
# GL (ref):  Cando se lle pediu que opinase, Miller afirmou: «Mike falou moito durante a vista… Eu estaba preparándome, polo que non estiven realmente a escoitar o que dicía».
# ------------------------------------------------------------
# EN: «Trabajaremos duro para reducir el nivel de dióxido de carbono emitido por unidad de PIB para el año 2020, de modo que la diferencia sea significativa en comparación con el 2005», afirmó Hu.
# GL (pred): «Travaremos duro para reducir o nivel de dióxido de carbono emitido nunha unidade de PIB para o ano 2020, de xeito a diferenza ser significativa fronte ao de 2005, afirmau Hu.
# GL (ref):  "Traballaremos para reducir as emisións de dióxido de carbono por unidade de PIB nunha medida importante para o 2020 en comparación co nivel de 2005", afirmou Hu.
# ------------------------------------------------------------
# EN: No mencionó una cifra para los recortes y manifestó que se harán en base a la producción económica de China.
# GL (pred): Non mencionou ningún número para a redución nin explicou que se realizaría na base da produción económica chinesa.
# GL (ref):  Non fixou unha cifra para os recortes e afirmou que se realizarían segundo a produción económica da China.
# ------------------------------------------------------------
# EN: Hu incentivó a los estados en vías de desarrollo a «no volver al tradicional camino de contaminar primero y hacer limpieza después».
# GL (pred): Instou aos países en vías de desenvolvemento a «non volver ao tipo tradicional de contaminar antes e limpar despois».
# GL (ref):  Hu animou aos países en vías de desenvolvemento a que «evitasen a vella ruta de contaminar primeiro e limpar despois».
# ------------------------------------------------------------
# EN: Agregó: «Aun así, no es correcto exigirles que asuman obligaciones que sobrepasan su fase de desarrollo, su nivel de responsabilidad y sus capacidades».
# GL (pred): Aínda que non é correcto exigirlles que cumplan obrigacións que superen a súa fase de desenvolvemento, seu nivel de responsabilidade e súas capacidades, agregou.
# GL (ref):  Engadiu que «non obstante, non se lles debía pedir que asumisen obrigas que fosen máis alá da fase de desenvolvemento, responsabilidades e capacidades».
# ------------------------------------------------------------
#
# 📊 Métricas globales:
# BLEU: 0.1943
# chrF: 50.41
